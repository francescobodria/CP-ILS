# %%
import pickle

d = pickle.load(open(f'./results/borderline_pairs.p','rb'))

# %%
d_dist
d_count
d_impl
d_adv
d_dist_pairs
d_count_pairs
d_pred_ex
d_pred_pairs

# %%
metric = 'd_dist'
dataset = 'compas'
print(metric)
print('XGB')
print(np.round(d[dataset]['xgb'][metric+'_ILS_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_ILS_std'],4))
print(np.round(d[dataset]['xgb'][metric+'_GS_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_GS_std'],4))
print(np.round(d[dataset]['xgb'][metric+'_WACH_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_WACH_std'],4))
print('SVC')
print(np.round(d[dataset]['svc'][metric+'_ILS_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_ILS_std'],4))
print(np.round(d[dataset]['svc'][metric+'_GS_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_GS_std'],4))
print(np.round(d[dataset]['svc'][metric+'_WACH_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_WACH_std'],4))
print('NN')
print(np.round(d[dataset]['nn'][metric+'_ILS_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_ILS_std'],4))
print(np.round(d[dataset]['nn'][metric+'_GS_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_GS_std'],4))
print(np.round(d[dataset]['nn'][metric+'_WACH_mean'],4),'+-',np.round(d[dataset]['xgb'][metric+'_WACH_std'],4))
# Out:
# d_dist
# XGB
# 1.1397 +- 0.7206
# 0.2823 +- 0.2433
# 3.4927 +- 0.0
# SVC
# 0.195 +- 0.7206
# 0.848 +- 0.2433
# 4.2682 +- 0.0
# NN
# 0.8728 +- 0.7206
# 0.9055 +- 0.2433
# 3.8736 +- 0.0

# %%
d
# Out:
# {'adult': {'xgb': {'d_dist_ILS_mean': 0.753655426333411,
#    'd_dist_ILS_std': 0.5517927848594487,
#    'd_count_ILS_mean': 0.33497536945812795,
#    'd_count_ILS_std': 0.1296480850124918,
#    'd_impl_ILS_mean': 0.6828022166071649,
#    'd_impl_ILS_std': 1.060632802008207,
#    'd_adv_ILS_mean': 0.6053677525097315,
#    'd_adv_ILS_std': 0.2242341926833931,
#    'd_dist_pairs_ILS_mean': 0.33830333237950144,
#    'd_dist_pairs_ILS_std': 0.3884823594833165,
#    'd_count_pairs_ILS_mean': 0.19211822660098515,
#    'd_count_pairs_ILS_std': 0.10348736457529542,
#    'd_pred_ex_ILS_mean': 0.16351844490259543,
#    'd_pred_ex_ILS_std': 0.1454673846535853,
#    'd_pred_pairs_ILS_mean': 0.24098569908361325,
#    'd_pred_pairs_ILS_std': 0.1722765034711221,
#    'd_dist_GS_mean': 0.27829277863806995,
#    'd_dist_GS_std': 0.19615505564825364,
#    'd_count_GS_mean': 0.25999999999999995,
#    'd_count_GS_std': 0.10950724512421026,
#    'd_impl_GS_mean': 0.27793162896433204,
# ...
